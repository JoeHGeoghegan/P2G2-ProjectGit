# %% [markdown]
# <a href="https://colab.research.google.com/gist/janlukasschroeder/3da274150fd00c1c1776c7e541a9b61b/extracting-financial-statements-from-sec-filings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extracting Financial Statements from SEC Filings - XBRL-To-JSON
#
# This is the entire Jupyter notebook to extract financial statements from annual and quarterly reports as reported in 10-K and 10-Q filings with the SEC.
#
# We use https://sec-api.io to get all 10-K and 10-Q filings and to convert their XBRL data into JSON so that we can create a single income statement, balance sheet and cash flow statement for Apple, covering quarterly financial data over multiple years.
#
# Medium article:
# https://medium.com/@jan_5421/extracting-financial-statements-from-sec-filings-xbrl-to-json-f83542ade90

# %%
# uncomment the next line to install the SEC API Python package
# pip install sec_api

# %%
#basic imports and env
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv('paid_sec_api_key')

# %%
import requests
import json
import pandas as pd

# 10-Q filing URL of Apple
filing_url = "https://www.sec.gov/Archives/edgar/data/320193/000032019321000056/aapl-20210327.htm"

# XBRL-to-JSON converter API endpoint
xbrl_converter_api_endpoint = "https://api.sec-api.io/xbrl-to-json"

final_url = xbrl_converter_api_endpoint + "?htm-url=" + filing_url + "&token=" + api_key

# make request to the API
response = requests.get(final_url)

# load JSON into memory
xbrl_json = json.loads(response.text)

# income statement example
print(json.dumps(xbrl_json['StatementsOfIncome'], indent=1))
# Out:
# {
#  "RevenueFromContractWithCustomerExcludingAssessedTax": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "72683000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "44965000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "168361000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "124069000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "16901000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "13348000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "32662000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "26063000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "89584000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "58313000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "201023000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "150132000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPhoneMember"
#    },
#    "value": "47938000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPhoneMember"
#    },
#    "value": "28962000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPhoneMember"
#    },
#    "value": "113535000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPhoneMember"
#    },
#    "value": "84919000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:MacMember"
#    },
#    "value": "9102000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:MacMember"
#    },
#    "value": "5351000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:MacMember"
#    },
#    "value": "17777000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:MacMember"
#    },
#    "value": "12511000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPadMember"
#    },
#    "value": "7807000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPadMember"
#    },
#    "value": "4368000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPadMember"
#    },
#    "value": "16242000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:IPadMember"
#    },
#    "value": "10345000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:WearablesHomeandAccessoriesMember"
#    },
#    "value": "7836000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:WearablesHomeandAccessoriesMember"
#    },
#    "value": "6284000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:WearablesHomeandAccessoriesMember"
#    },
#    "value": "20807000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "aapl:WearablesHomeandAccessoriesMember"
#    },
#    "value": "16294000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "34306000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "25473000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "80616000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "66840000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "22264000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "14294000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "49570000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "37567000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "17728000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "9455000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "39041000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "23033000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "7742000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "5206000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "16027000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "11429000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "7544000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "3885000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "15769000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "11263000000"
#   }
#  ],
#  "CostOfGoodsAndServicesSold": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "46447000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "31321000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "108577000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ProductMember"
#    },
#    "value": "83396000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "5058000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "4622000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "10039000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ProductOrServiceAxis",
#     "value": "us-gaap:ServiceMember"
#    },
#    "value": "9149000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "51505000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "35943000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "118616000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "92545000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "406000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "12000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "651000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-159000000"
#   }
#  ],
#  "GrossProfit": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "38079000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "22370000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "82407000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "57587000000"
#   }
#  ],
#  "ResearchAndDevelopmentExpense": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "5262000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "4565000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "10425000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "9016000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:MaterialReconcilingItemsMember"
#    },
#    "value": "5262000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:MaterialReconcilingItemsMember"
#    },
#    "value": "4565000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:MaterialReconcilingItemsMember"
#    },
#    "value": "10425000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:MaterialReconcilingItemsMember"
#    },
#    "value": "9016000000"
#   }
#  ],
#  "SellingGeneralAndAdministrativeExpense": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "5314000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "4952000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "10945000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "10149000000"
#   }
#  ],
#  "OperatingExpenses": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "10576000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "9517000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "21370000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "19165000000"
#   }
#  ],
#  "OperatingIncomeLoss": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "27503000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "12853000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "61037000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "38422000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "12050000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "7261000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "27835000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:AmericasSegmentMember"
#    },
#    "value": "20353000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "8265000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "4528000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "17854000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:EuropeSegmentMember"
#    },
#    "value": "12247000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "7758000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "3758000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "16288000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:GreaterChinaSegmentMember"
#    },
#    "value": "9121000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "3428000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "2236000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "6931000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:JapanSegmentMember"
#    },
#    "value": "5014000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "2736000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "1290000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "5689000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementBusinessSegmentsAxis",
#     "value": "aapl:RestOfAsiaPacificSegmentMember"
#    },
#    "value": "4021000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:OperatingSegmentsMember"
#    },
#    "value": "34237000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:OperatingSegmentsMember"
#    },
#    "value": "19073000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:OperatingSegmentsMember"
#    },
#    "value": "74597000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "srt:ConsolidationItemsAxis",
#     "value": "us-gaap:OperatingSegmentsMember"
#    },
#    "value": "50756000000"
#   }
#  ],
#  "NonoperatingIncomeExpense": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "508000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "282000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "553000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "631000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-193000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-771000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "435000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:ForeignExchangeContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-548000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:InterestRateContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-2000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:InterestRateContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-1000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:InterestRateContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-5000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:DerivativeInstrumentRiskAxis",
#      "value": "us-gaap:InterestRateContractMember"
#     },
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-3000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "us-gaap:AccumulatedNetUnrealizedInvestmentGainLossMember"
#     }
#    ],
#    "value": "96000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "us-gaap:AccumulatedNetUnrealizedInvestmentGainLossMember"
#     }
#    ],
#    "value": "-37000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "us-gaap:AccumulatedNetUnrealizedInvestmentGainLossMember"
#     }
#    ],
#    "value": "214000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "us-gaap:AccumulatedNetUnrealizedInvestmentGainLossMember"
#     }
#    ],
#    "value": "-24000000"
#   }
#  ],
#  "IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "28011000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "13135000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "61590000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "39053000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-915000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-818000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-639000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": [
#     {
#      "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#      "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#     },
#     {
#      "dimension": "us-gaap:StatementEquityComponentsAxis",
#      "value": "aapl:AccumulatedGainLossNetDerivativeInstrumentParentMember"
#     }
#    ],
#    "value": "-329000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#     "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#    },
#    "value": "-819000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#     "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#    },
#    "value": "-855000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#     "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#    },
#    "value": "-425000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeAxis",
#     "value": "us-gaap:ReclassificationOutOfAccumulatedOtherComprehensiveIncomeMember"
#    },
#    "value": "-353000000"
#   }
#  ],
#  "IncomeTaxExpenseBenefit": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "4381000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "1886000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "9205000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "5568000000"
#   }
#  ],
#  "NetIncomeLoss": [
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "23630000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "11249000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "52385000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "33485000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementEquityComponentsAxis",
#     "value": "us-gaap:RetainedEarningsMember"
#    },
#    "value": "23630000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementEquityComponentsAxis",
#     "value": "us-gaap:RetainedEarningsMember"
#    },
#    "value": "11249000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementEquityComponentsAxis",
#     "value": "us-gaap:RetainedEarningsMember"
#    },
#    "value": "52385000000"
#   },
#   {
#    "decimals": "-6",
#    "unitRef": "usd",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "segment": {
#     "dimension": "us-gaap:StatementEquityComponentsAxis",
#     "value": "us-gaap:RetainedEarningsMember"
#    },
#    "value": "33485000000"
#   }
#  ],
#  "EarningsPerShareBasic": [
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "1.41"
#   },
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "0.64"
#   },
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "3.11"
#   },
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "1.91"
#   }
#  ],
#  "EarningsPerShareDiluted": [
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "1.40"
#   },
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "0.64"
#   },
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "3.08"
#   },
#   {
#    "decimals": "2",
#    "unitRef": "usdPerShare",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "1.89"
#   }
#  ],
#  "WeightedAverageNumberOfSharesOutstandingBasic": [
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "16753476000"
#   },
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "17440402000"
#   },
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "16844298000"
#   },
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "17550281000"
#   }
#  ],
#  "WeightedAverageNumberOfDilutedSharesOutstanding": [
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2020-12-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "16929157000"
#   },
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2019-12-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "17618765000"
#   },
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2020-09-27",
#     "endDate": "2021-03-27"
#    },
#    "value": "17021423000"
#   },
#   {
#    "decimals": "-3",
#    "unitRef": "shares",
#    "period": {
#     "startDate": "2019-09-29",
#     "endDate": "2020-03-28"
#    },
#    "value": "17718591000"
#   }
#  ]
# }

# %%
# convert XBRL-JSON of income statement to pandas dataframe
def get_income_statement(xbrl_json):
    income_statement_store = {}

    # iterate over each US GAAP item in the income statement
    for usGaapItem in xbrl_json['StatementsOfIncome']:
        values = []
        indicies = []

        for fact in xbrl_json['StatementsOfIncome'][usGaapItem]:
            # only consider items without segment. not required for our analysis.
            if 'segment' not in fact:
                index = fact['period']['startDate'] + '-' + fact['period']['endDate']
                # ensure no index duplicates are created
                if index not in indicies:
                    values.append(fact['value'])
                    indicies.append(index)                    

        income_statement_store[usGaapItem] = pd.Series(values, index=indicies) 

    income_statement = pd.DataFrame(income_statement_store)
    # switch columns and rows so that US GAAP items are rows and each column header represents a date range
    return income_statement.T 

income_statement = get_income_statement(xbrl_json)

# %%
income_statement
# Out:
#                                                    2020-12-27-2021-03-27  \
# RevenueFromContractWithCustomerExcludingAssesse...           89584000000
# CostOfGoodsAndServicesSold                                   51505000000
# GrossProfit                                                  38079000000
# ResearchAndDevelopmentExpense                                 5262000000
# SellingGeneralAndAdministrativeExpense                        5314000000
# OperatingExpenses                                            10576000000
# OperatingIncomeLoss                                          27503000000
# NonoperatingIncomeExpense                                      508000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           28011000000
# IncomeTaxExpenseBenefit                                       4381000000
# NetIncomeLoss                                                23630000000
# EarningsPerShareBasic                                               1.41
# EarningsPerShareDiluted                                             1.40
# WeightedAverageNumberOfSharesOutstandingBasic                16753476000
# WeightedAverageNumberOfDilutedSharesOutstanding              16929157000
#
#                                                    2019-12-29-2020-03-28  \
# RevenueFromContractWithCustomerExcludingAssesse...           58313000000
# CostOfGoodsAndServicesSold                                   35943000000
# GrossProfit                                                  22370000000
# ResearchAndDevelopmentExpense                                 4565000000
# SellingGeneralAndAdministrativeExpense                        4952000000
# OperatingExpenses                                             9517000000
# OperatingIncomeLoss                                          12853000000
# NonoperatingIncomeExpense                                      282000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           13135000000
# IncomeTaxExpenseBenefit                                       1886000000
# NetIncomeLoss                                                11249000000
# EarningsPerShareBasic                                               0.64
# EarningsPerShareDiluted                                             0.64
# WeightedAverageNumberOfSharesOutstandingBasic                17440402000
# WeightedAverageNumberOfDilutedSharesOutstanding              17618765000
#
#                                                    2020-09-27-2021-03-27  \
# RevenueFromContractWithCustomerExcludingAssesse...          201023000000
# CostOfGoodsAndServicesSold                                  118616000000
# GrossProfit                                                  82407000000
# ResearchAndDevelopmentExpense                                10425000000
# SellingGeneralAndAdministrativeExpense                       10945000000
# OperatingExpenses                                            21370000000
# OperatingIncomeLoss                                          61037000000
# NonoperatingIncomeExpense                                      553000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           61590000000
# IncomeTaxExpenseBenefit                                       9205000000
# NetIncomeLoss                                                52385000000
# EarningsPerShareBasic                                               3.11
# EarningsPerShareDiluted                                             3.08
# WeightedAverageNumberOfSharesOutstandingBasic                16844298000
# WeightedAverageNumberOfDilutedSharesOutstanding              17021423000
#
#                                                    2019-09-29-2020-03-28
# RevenueFromContractWithCustomerExcludingAssesse...          150132000000
# CostOfGoodsAndServicesSold                                   92545000000
# GrossProfit                                                  57587000000
# ResearchAndDevelopmentExpense                                 9016000000
# SellingGeneralAndAdministrativeExpense                       10149000000
# OperatingExpenses                                            19165000000
# OperatingIncomeLoss                                          38422000000
# NonoperatingIncomeExpense                                      631000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           39053000000
# IncomeTaxExpenseBenefit                                       5568000000
# NetIncomeLoss                                                33485000000
# EarningsPerShareBasic                                               1.91
# EarningsPerShareDiluted                                             1.89
# WeightedAverageNumberOfSharesOutstandingBasic                17550281000
# WeightedAverageNumberOfDilutedSharesOutstanding              17718591000

# %%
# convert XBRL-JSON of balance sheet to pandas dataframe
def get_balance_sheet(xbrl_json):
    balance_sheet_store = {}

    for usGaapItem in xbrl_json['BalanceSheets']:
        values = []
        indicies = []

        for fact in xbrl_json['BalanceSheets'][usGaapItem]:
            # only consider items without segment.
            if 'segment' not in fact:
                index = fact['period']['instant']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue
                    
                # add 0 if value is nil
                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    

            balance_sheet_store[usGaapItem] = pd.Series(values, index=indicies) 

    balance_sheet = pd.DataFrame(balance_sheet_store)
    # switch columns and rows so that US GAAP items are rows and each column header represents a date instant
    return balance_sheet.T

balance_sheet = get_balance_sheet(xbrl_json)

# %%
balance_sheet
# Out:
#                                                   2019-09-28   2019-12-28  \
# CashAndCashEquivalentsAtCarryingValue                    NaN          NaN
# MarketableSecuritiesCurrent                              NaN          NaN
# AccountsReceivableNetCurrent                             NaN          NaN
# InventoryNet                                             NaN          NaN
# NontradeReceivablesCurrent                               NaN          NaN
# OtherAssetsCurrent                                       NaN          NaN
# AssetsCurrent                                            NaN          NaN
# MarketableSecuritiesNoncurrent                           NaN          NaN
# PropertyPlantAndEquipmentNet                             NaN          NaN
# OtherAssetsNoncurrent                                    NaN          NaN
# AssetsNoncurrent                                         NaN          NaN
# Assets                                                   NaN          NaN
# AccountsPayableCurrent                                   NaN          NaN
# OtherLiabilitiesCurrent                                  NaN          NaN
# ContractWithCustomerLiabilityCurrent                     NaN          NaN
# CommercialPaper                                          NaN          NaN
# LongTermDebtCurrent                                      NaN          NaN
# LiabilitiesCurrent                                       NaN          NaN
# LongTermDebtNoncurrent                                   NaN          NaN
# OtherLiabilitiesNoncurrent                               NaN          NaN
# LiabilitiesNoncurrent                                    NaN          NaN
# Liabilities                                              NaN          NaN
# CommitmentsAndContingencies                              NaN          NaN
# CommonStocksIncludingAdditionalPaidInCapital             NaN          NaN
# RetainedEarningsAccumulatedDeficit                       NaN          NaN
# AccumulatedOtherComprehensiveIncomeLossNetOfTax          NaN          NaN
# StockholdersEquity                               90488000000  89531000000
# LiabilitiesAndStockholdersEquity                         NaN          NaN
#
#                                                   2020-03-28    2020-09-26  \
# CashAndCashEquivalentsAtCarryingValue                    NaN   38016000000
# MarketableSecuritiesCurrent                              NaN   52927000000
# AccountsReceivableNetCurrent                             NaN   16120000000
# InventoryNet                                             NaN    4061000000
# NontradeReceivablesCurrent                               NaN   21325000000
# OtherAssetsCurrent                                       NaN   11264000000
# AssetsCurrent                                            NaN  143713000000
# MarketableSecuritiesNoncurrent                           NaN  100887000000
# PropertyPlantAndEquipmentNet                             NaN   36766000000
# OtherAssetsNoncurrent                                    NaN   42522000000
# AssetsNoncurrent                                         NaN  180175000000
# Assets                                                   NaN  323888000000
# AccountsPayableCurrent                                   NaN   42296000000
# OtherLiabilitiesCurrent                                  NaN   42684000000
# ContractWithCustomerLiabilityCurrent                     NaN    6643000000
# CommercialPaper                                          NaN    4996000000
# LongTermDebtCurrent                                      NaN    8773000000
# LiabilitiesCurrent                                       NaN  105392000000
# LongTermDebtNoncurrent                                   NaN   98667000000
# OtherLiabilitiesNoncurrent                               NaN   54490000000
# LiabilitiesNoncurrent                                    NaN  153157000000
# Liabilities                                              NaN  258549000000
# CommitmentsAndContingencies                              NaN           0.0
# CommonStocksIncludingAdditionalPaidInCapital             NaN   50779000000
# RetainedEarningsAccumulatedDeficit                       NaN   14966000000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax          NaN    -406000000
# StockholdersEquity                               78425000000   65339000000
# LiabilitiesAndStockholdersEquity                         NaN  323888000000
#
#                                                   2020-12-26    2021-03-27
# CashAndCashEquivalentsAtCarryingValue                    NaN   38466000000
# MarketableSecuritiesCurrent                              NaN   31368000000
# AccountsReceivableNetCurrent                             NaN   18503000000
# InventoryNet                                             NaN    5219000000
# NontradeReceivablesCurrent                               NaN   14533000000
# OtherAssetsCurrent                                       NaN   13376000000
# AssetsCurrent                                            NaN  121465000000
# MarketableSecuritiesNoncurrent                           NaN  134539000000
# PropertyPlantAndEquipmentNet                             NaN   37815000000
# OtherAssetsNoncurrent                                    NaN   43339000000
# AssetsNoncurrent                                         NaN  215693000000
# Assets                                                   NaN  337158000000
# AccountsPayableCurrent                                   NaN   40127000000
# OtherLiabilitiesCurrent                                  NaN   45660000000
# ContractWithCustomerLiabilityCurrent                     NaN    7595000000
# CommercialPaper                                          NaN    5000000000
# LongTermDebtCurrent                                      NaN    8003000000
# LiabilitiesCurrent                                       NaN  106385000000
# LongTermDebtNoncurrent                                   NaN  108642000000
# OtherLiabilitiesNoncurrent                               NaN   52953000000
# LiabilitiesNoncurrent                                    NaN  161595000000
# Liabilities                                              NaN  267980000000
# CommitmentsAndContingencies                              NaN           0.0
# CommonStocksIncludingAdditionalPaidInCapital             NaN   54203000000
# RetainedEarningsAccumulatedDeficit                       NaN   15261000000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax          NaN    -286000000
# StockholdersEquity                               66224000000   69178000000
# LiabilitiesAndStockholdersEquity                         NaN  337158000000

# %%
def get_cash_flow_statement(xbrl_json):
    cash_flows_store = {}

    for usGaapItem in xbrl_json['StatementsOfCashFlows']:
        values = []
        indicies = []

        for fact in xbrl_json['StatementsOfCashFlows'][usGaapItem]:        
            # only consider items without segment.
            if 'segment' not in fact:
                # check if date instant or date range is present
                if "instant" in fact['period']:
                    index = fact['period']['instant']
                else:
                    index = fact['period']['startDate'] + '-' + fact['period']['endDate']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue

                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    

        cash_flows_store[usGaapItem] = pd.Series(values, index=indicies) 


    cash_flows = pd.DataFrame(cash_flows_store)
    return cash_flows.T
    
cash_flows = get_cash_flow_statement(xbrl_json)

# %%
cash_flows
# Out:
#                                                      2019-09-28  \
# CashCashEquivalentsRestrictedCashAndRestrictedC...  50224000000
# NetIncomeLoss                                               NaN
# DepreciationDepletionAndAmortization                        NaN
# ShareBasedCompensation                                      NaN
# DeferredIncomeTaxExpenseBenefit                             NaN
# OtherNoncashIncomeExpense                                   NaN
# IncreaseDecreaseInAccountsReceivable                        NaN
# IncreaseDecreaseInInventories                               NaN
# IncreaseDecreaseInOtherReceivables                          NaN
# IncreaseDecreaseInOtherOperatingAssets                      NaN
# IncreaseDecreaseInAccountsPayable                           NaN
# IncreaseDecreaseInContractWithCustomerLiability             NaN
# IncreaseDecreaseInOtherOperatingLiabilities                 NaN
# NetCashProvidedByUsedInOperatingActivities                  NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt             NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...          NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt            NaN
# PaymentsToAcquirePropertyPlantAndEquipment                  NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired                NaN
# PaymentsForProceedsFromOtherInvestingActivities             NaN
# NetCashProvidedByUsedInInvestingActivities                  NaN
# ProceedsFromIssuanceOfCommonStock                           NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...          NaN
# PaymentsOfDividends                                         NaN
# PaymentsForRepurchaseOfCommonStock                          NaN
# ProceedsFromIssuanceOfLongTermDebt                          NaN
# RepaymentsOfLongTermDebt                                    NaN
# ProceedsFromRepaymentsOfCommercialPaper                     NaN
# ProceedsFromOtherShortTermDebt                              NaN
# ProceedsFromPaymentsForOtherFinancingActivities             NaN
# NetCashProvidedByUsedInFinancingActivities                  NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...          NaN
# IncomeTaxesPaidNet                                          NaN
# InterestPaidNet                                             NaN
#
#                                                    2019-09-29-2020-03-28  \
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# NetIncomeLoss                                                33485000000
# DepreciationDepletionAndAmortization                          5602000000
# ShareBasedCompensation                                        3407000000
# DeferredIncomeTaxExpenseBenefit                               -651000000
# OtherNoncashIncomeExpense                                      259000000
# IncreaseDecreaseInAccountsReceivable                         -7284000000
# IncreaseDecreaseInInventories                                 -699000000
# IncreaseDecreaseInOtherReceivables                           -7923000000
# IncreaseDecreaseInOtherOperatingAssets                        8866000000
# IncreaseDecreaseInAccountsPayable                           -13520000000
# IncreaseDecreaseInContractWithCustomerLiability               1223000000
# IncreaseDecreaseInOtherOperatingLiabilities                   7500000000
# NetCashProvidedByUsedInOperatingActivities                   43827000000
# PaymentsToAcquireAvailableForSaleSecuritiesDebt              66489000000
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...           39738000000
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt             27762000000
# PaymentsToAcquirePropertyPlantAndEquipment                    3960000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                  1134000000
# PaymentsForProceedsFromOtherInvestingActivities                572000000
# NetCashProvidedByUsedInInvestingActivities                   -4655000000
# ProceedsFromIssuanceOfCommonStock                              430000000
# PaymentsRelatedToTaxWithholdingForShareBasedCom...            1566000000
# PaymentsOfDividends                                           6914000000
# PaymentsForRepurchaseOfCommonStock                           39280000000
# ProceedsFromIssuanceOfLongTermDebt                            2210000000
# RepaymentsOfLongTermDebt                                      5250000000
# ProceedsFromRepaymentsOfCommercialPaper                       1518000000
# ProceedsFromOtherShortTermDebt                                2556000000
# ProceedsFromPaymentsForOtherFinancingActivities                -51000000
# NetCashProvidedByUsedInFinancingActivities                  -46347000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...           -7175000000
# IncomeTaxesPaidNet                                            7505000000
# InterestPaidNet                                               1689000000
#
#                                                    2019-12-29-2020-03-28  \
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# NetIncomeLoss                                                11249000000
# DepreciationDepletionAndAmortization                                 NaN
# ShareBasedCompensation                                               NaN
# DeferredIncomeTaxExpenseBenefit                                      NaN
# OtherNoncashIncomeExpense                                            NaN
# IncreaseDecreaseInAccountsReceivable                                 NaN
# IncreaseDecreaseInInventories                                        NaN
# IncreaseDecreaseInOtherReceivables                                   NaN
# IncreaseDecreaseInOtherOperatingAssets                               NaN
# IncreaseDecreaseInAccountsPayable                                    NaN
# IncreaseDecreaseInContractWithCustomerLiability                      NaN
# IncreaseDecreaseInOtherOperatingLiabilities                          NaN
# NetCashProvidedByUsedInOperatingActivities                           NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt                      NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...                   NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt                     NaN
# PaymentsToAcquirePropertyPlantAndEquipment                           NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired                         NaN
# PaymentsForProceedsFromOtherInvestingActivities                      NaN
# NetCashProvidedByUsedInInvestingActivities                           NaN
# ProceedsFromIssuanceOfCommonStock                                    NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...                   NaN
# PaymentsOfDividends                                                  NaN
# PaymentsForRepurchaseOfCommonStock                                   NaN
# ProceedsFromIssuanceOfLongTermDebt                                   NaN
# RepaymentsOfLongTermDebt                                             NaN
# ProceedsFromRepaymentsOfCommercialPaper                              NaN
# ProceedsFromOtherShortTermDebt                                       NaN
# ProceedsFromPaymentsForOtherFinancingActivities                      NaN
# NetCashProvidedByUsedInFinancingActivities                           NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# IncomeTaxesPaidNet                                                   NaN
# InterestPaidNet                                                      NaN
#
#                                                      2020-03-28   2020-09-26  \
# CashCashEquivalentsRestrictedCashAndRestrictedC...  43049000000  39789000000
# NetIncomeLoss                                               NaN          NaN
# DepreciationDepletionAndAmortization                        NaN          NaN
# ShareBasedCompensation                                      NaN          NaN
# DeferredIncomeTaxExpenseBenefit                             NaN          NaN
# OtherNoncashIncomeExpense                                   NaN          NaN
# IncreaseDecreaseInAccountsReceivable                        NaN          NaN
# IncreaseDecreaseInInventories                               NaN          NaN
# IncreaseDecreaseInOtherReceivables                          NaN          NaN
# IncreaseDecreaseInOtherOperatingAssets                      NaN          NaN
# IncreaseDecreaseInAccountsPayable                           NaN          NaN
# IncreaseDecreaseInContractWithCustomerLiability             NaN          NaN
# IncreaseDecreaseInOtherOperatingLiabilities                 NaN          NaN
# NetCashProvidedByUsedInOperatingActivities                  NaN          NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt             NaN          NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...          NaN          NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt            NaN          NaN
# PaymentsToAcquirePropertyPlantAndEquipment                  NaN          NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired                NaN          NaN
# PaymentsForProceedsFromOtherInvestingActivities             NaN          NaN
# NetCashProvidedByUsedInInvestingActivities                  NaN          NaN
# ProceedsFromIssuanceOfCommonStock                           NaN          NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...          NaN          NaN
# PaymentsOfDividends                                         NaN          NaN
# PaymentsForRepurchaseOfCommonStock                          NaN          NaN
# ProceedsFromIssuanceOfLongTermDebt                          NaN          NaN
# RepaymentsOfLongTermDebt                                    NaN          NaN
# ProceedsFromRepaymentsOfCommercialPaper                     NaN          NaN
# ProceedsFromOtherShortTermDebt                              NaN          NaN
# ProceedsFromPaymentsForOtherFinancingActivities             NaN          NaN
# NetCashProvidedByUsedInFinancingActivities                  NaN          NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...          NaN          NaN
# IncomeTaxesPaidNet                                          NaN          NaN
# InterestPaidNet                                             NaN          NaN
#
#                                                    2020-09-27-2021-03-27  \
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# NetIncomeLoss                                                52385000000
# DepreciationDepletionAndAmortization                          5463000000
# ShareBasedCompensation                                        4001000000
# DeferredIncomeTaxExpenseBenefit                               -207000000
# OtherNoncashIncomeExpense                                      474000000
# IncreaseDecreaseInAccountsReceivable                          2347000000
# IncreaseDecreaseInInventories                                 1226000000
# IncreaseDecreaseInOtherReceivables                           -6792000000
# IncreaseDecreaseInOtherOperatingAssets                        4333000000
# IncreaseDecreaseInAccountsPayable                            -1997000000
# IncreaseDecreaseInContractWithCustomerLiability               1642000000
# IncreaseDecreaseInOtherOperatingLiabilities                   3045000000
# NetCashProvidedByUsedInOperatingActivities                   62744000000
# PaymentsToAcquireAvailableForSaleSecuritiesDebt              74424000000
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...           39605000000
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt             21645000000
# PaymentsToAcquirePropertyPlantAndEquipment                    5769000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                     9000000
# PaymentsForProceedsFromOtherInvestingActivities                        0
# NetCashProvidedByUsedInInvestingActivities                  -18952000000
# ProceedsFromIssuanceOfCommonStock                              561000000
# PaymentsRelatedToTaxWithholdingForShareBasedCom...            3160000000
# PaymentsOfDividends                                           7060000000
# PaymentsForRepurchaseOfCommonStock                           43323000000
# ProceedsFromIssuanceOfLongTermDebt                           13923000000
# RepaymentsOfLongTermDebt                                      4500000000
# ProceedsFromRepaymentsOfCommercialPaper                         22000000
# ProceedsFromOtherShortTermDebt                                         0
# ProceedsFromPaymentsForOtherFinancingActivities                -38000000
# NetCashProvidedByUsedInFinancingActivities                  -43575000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...             217000000
# IncomeTaxesPaidNet                                           10276000000
# InterestPaidNet                                               1327000000
#
#                                                    2020-12-27-2021-03-27  \
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# NetIncomeLoss                                                23630000000
# DepreciationDepletionAndAmortization                                 NaN
# ShareBasedCompensation                                               NaN
# DeferredIncomeTaxExpenseBenefit                                      NaN
# OtherNoncashIncomeExpense                                            NaN
# IncreaseDecreaseInAccountsReceivable                                 NaN
# IncreaseDecreaseInInventories                                        NaN
# IncreaseDecreaseInOtherReceivables                                   NaN
# IncreaseDecreaseInOtherOperatingAssets                               NaN
# IncreaseDecreaseInAccountsPayable                                    NaN
# IncreaseDecreaseInContractWithCustomerLiability                      NaN
# IncreaseDecreaseInOtherOperatingLiabilities                          NaN
# NetCashProvidedByUsedInOperatingActivities                           NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt                      NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...                   NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt                     NaN
# PaymentsToAcquirePropertyPlantAndEquipment                           NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired                         NaN
# PaymentsForProceedsFromOtherInvestingActivities                      NaN
# NetCashProvidedByUsedInInvestingActivities                           NaN
# ProceedsFromIssuanceOfCommonStock                                    NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...                   NaN
# PaymentsOfDividends                                                  NaN
# PaymentsForRepurchaseOfCommonStock                                   NaN
# ProceedsFromIssuanceOfLongTermDebt                                   NaN
# RepaymentsOfLongTermDebt                                             NaN
# ProceedsFromRepaymentsOfCommercialPaper                              NaN
# ProceedsFromOtherShortTermDebt                                       NaN
# ProceedsFromPaymentsForOtherFinancingActivities                      NaN
# NetCashProvidedByUsedInFinancingActivities                           NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# IncomeTaxesPaidNet                                                   NaN
# InterestPaidNet                                                      NaN
#
#                                                      2021-03-27
# CashCashEquivalentsRestrictedCashAndRestrictedC...  40006000000
# NetIncomeLoss                                               NaN
# DepreciationDepletionAndAmortization                        NaN
# ShareBasedCompensation                                      NaN
# DeferredIncomeTaxExpenseBenefit                             NaN
# OtherNoncashIncomeExpense                                   NaN
# IncreaseDecreaseInAccountsReceivable                        NaN
# IncreaseDecreaseInInventories                               NaN
# IncreaseDecreaseInOtherReceivables                          NaN
# IncreaseDecreaseInOtherOperatingAssets                      NaN
# IncreaseDecreaseInAccountsPayable                           NaN
# IncreaseDecreaseInContractWithCustomerLiability             NaN
# IncreaseDecreaseInOtherOperatingLiabilities                 NaN
# NetCashProvidedByUsedInOperatingActivities                  NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt             NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...          NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt            NaN
# PaymentsToAcquirePropertyPlantAndEquipment                  NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired                NaN
# PaymentsForProceedsFromOtherInvestingActivities             NaN
# NetCashProvidedByUsedInInvestingActivities                  NaN
# ProceedsFromIssuanceOfCommonStock                           NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...          NaN
# PaymentsOfDividends                                         NaN
# PaymentsForRepurchaseOfCommonStock                          NaN
# ProceedsFromIssuanceOfLongTermDebt                          NaN
# RepaymentsOfLongTermDebt                                    NaN
# ProceedsFromRepaymentsOfCommercialPaper                     NaN
# ProceedsFromOtherShortTermDebt                              NaN
# ProceedsFromPaymentsForOtherFinancingActivities             NaN
# NetCashProvidedByUsedInFinancingActivities                  NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...          NaN
# IncomeTaxesPaidNet                                          NaN
# InterestPaidNet                                             NaN

# %%
from sec_api import QueryApi

# get your API key at https://sec-api.io
query_api = QueryApi(api_key=api_key)

# fetch all 10-Q and 10-K filings for Apple
query = {
    "query": {
        "query_string": {
            "query": "(formType:\"10-Q\" OR formType:\"10-K\") AND ticker:ABNB"
        }
    },
    "from": "0",
    "size": "20",
    "sort": [{ "filedAt": { "order": "desc" } }]
}

query_result = query_api.get_filings(query)

# %%
accession_numbers = []

# extract accession numbers of each filing
for filing in query_result['filings']:
    accession_numbers.append(filing['accessionNo']);

accession_numbers
# Out:
# ['0001559720-22-000009',
#  '0001559720-22-000006',
#  '0001559720-21-000017',
#  '0001628280-21-016979',
#  '0001628280-21-010389',
#  '0001559720-21-000010']

# %%
import time

# get XBRL-JSON for a given accession number
def get_xbrl_json(accession_no, retry = 0):
    request_url = xbrl_converter_api_endpoint + "?accession-no=" + accession_no + "&token=" + api_key

    # linear backoff in case API fails with "too many requests" error
    try:
      response_tmp = requests.get(request_url)
      xbrl_json = json.loads(response_tmp.text)
    except:
      if retry > 5:
        raise Exception('API error')
      
      # wait 500 milliseconds on error and retry
      time.sleep(0.5) 
      return get_xbrl_json(accession_no, retry + 1)

    return xbrl_json

# %%
# clean income statement.
# drop duplicate columns (= column name ends with "_left"), drop key_0 column, drop columns with +5 NaNs
def clean_income_statement(statement):
    for column in statement:

        # column has more than 5 NaN values
        is_nan_column = statement[column].isna().sum() > 5

        if column.endswith('_left') or column == 'key_0' or is_nan_column:
            statement = statement.drop(column, axis=1)
    
    # rearrange columns so that first column represents first quarter
    # e.g. 2018, 2019, 2020 - and not 2020, 2019, 2018
    sorted_columns = sorted(statement.columns.values)
    
    return statement[sorted_columns]

# %%
# merge two income statements into one statement.
# row indicies of both statements have to be the same
# statement_b represents the most recent statement.
def merge_income_statements(statement_a, statement_b):
    return statement_a.merge(statement_b,
                     how="outer", 
                    #  on=statement_b.index, 
                    right_on=statement_b.index, 
                     left_index=True,
                    #  right_index=True,
                     suffixes=('_left', ''))

# %%
# helps printing dataframes while we generate new income statement
from IPython.display import display, HTML

previous_income_statement_set = False
income_statement_final = None

for accession_no in accession_numbers[0:12]:
# for accession_no in accession_numbers: # doesn't work with filings filed before 2017 - indicies not equal
    print('Processing: ' + accession_no)
    try:
        # get XBRL-JSON of 10-Q or 10-K filing by accession number
        xbrl_json_data = get_xbrl_json(accession_no)
        
        # convert XBRL-JSON to a pandas dataframe
        income_statement_uncleaned = get_income_statement(xbrl_json_data)

        # clean the income statement
        income_statement_cleaned = clean_income_statement(income_statement_uncleaned)
        
        # print income statement on each iteration to monitor progress
        # display(HTML(income_statement_cleaned.to_html()))
        
        # merge new income statement with previously generated income statement
        if previous_income_statement_set:
            income_statement_final = clean_income_statement(merge_income_statements(income_statement_final, income_statement_cleaned))
        else:
            income_statement_final = income_statement_cleaned
            previous_income_statement_set = True
    except:
            continue
# Out:
# Processing: 0001559720-22-000009
# Processing: 0001559720-22-000006
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Processing: 0001559720-21-000017
# Processing: 0001628280-21-016979
# Processing: 0001628280-21-010389
# Processing: 0001559720-21-000010

# %%
income_statement_final
# Out:
#                                                    2019-01-01-2019-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            4805239000
# CostOfRevenue                                                 1196313000
# OperationsAndSupportExpense                                    815074000
# ResearchAndDevelopmentExpense                                  976695000
# SellingAndMarketingExpense                                    1621519000
# GeneralAndAdministrativeExpense                                697181000
# RestructuringCharges                                                   0
# CostsAndExpenses                                              5306782000
# OperatingIncomeLoss                                           -501543000
# InvestmentIncomeNonoperating                                    85902000
# InterestIncomeExpenseNonoperatingNet                            -9968000
# OtherNonoperatingIncomeExpense                                  13906000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -411703000
# IncomeTaxExpenseBenefit                                        262636000
# NetIncomeLoss                                                 -674339000
# IncomeLossFromContinuingOperationsPerBasicShare                      NaN
# IncomeLossFromContinuingOperationsPerDilutedShare                    NaN
# WeightedAverageNumberOfSharesOutstandingBasic                  260556000
# WeightedAverageNumberOfDilutedSharesOutstanding                260556000
#
#                                                    2020-01-01-2020-03-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             841830000
# CostOfRevenue                                                  277772000
# OperationsAndSupportExpense                                    221787000
# ResearchAndDevelopmentExpense                                  258819000
# SellingAndMarketingExpense                                     317179000
# GeneralAndAdministrativeExpense                                 91762000
# RestructuringCharges                                                   0
# CostsAndExpenses                                              1167319000
# OperatingIncomeLoss                                           -325489000
# InvestmentIncomeNonoperating                                    13649000
# InterestIncomeExpenseNonoperatingNet                             1510000
# OtherNonoperatingIncomeExpense                                 -46760000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -357090000
# IncomeTaxExpenseBenefit                                        -16485000
# NetIncomeLoss                                                 -340605000
# IncomeLossFromContinuingOperationsPerBasicShare                    -1.30
# IncomeLossFromContinuingOperationsPerDilutedShare                  -1.30
# WeightedAverageNumberOfSharesOutstandingBasic                  262509000
# WeightedAverageNumberOfDilutedSharesOutstanding                262509000
#
#                                                    2020-01-01-2020-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1176604000
# CostOfRevenue                                                  438970000
# OperationsAndSupportExpense                                    382263000
# ResearchAndDevelopmentExpense                                  476757000
# SellingAndMarketingExpense                                     432016000
# GeneralAndAdministrativeExpense                                241061000
# RestructuringCharges                                           114241000
# CostsAndExpenses                                              2085308000
# OperatingIncomeLoss                                           -908704000
# InvestmentIncomeNonoperating                                    19505000
# InterestIncomeExpenseNonoperatingNet                           -47681000
# OtherNonoperatingIncomeExpense                                 -59608000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -996488000
# IncomeTaxExpenseBenefit                                        -80295000
# NetIncomeLoss                                                 -916193000
# IncomeLossFromContinuingOperationsPerBasicShare                    -3.48
# IncomeLossFromContinuingOperationsPerDilutedShare                  -3.48
# WeightedAverageNumberOfSharesOutstandingBasic                  263013000
# WeightedAverageNumberOfDilutedSharesOutstanding                263013000
#
#                                                    2020-01-01-2020-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2518935000
# CostOfRevenue                                                  666295000
# OperationsAndSupportExpense                                    548369000
# ResearchAndDevelopmentExpense                                  690677000
# SellingAndMarketingExpense                                     545510000
# GeneralAndAdministrativeExpense                                421082000
# RestructuringCharges                                           136969000
# CostsAndExpenses                                              3008902000
# OperatingIncomeLoss                                           -489967000
# InvestmentIncomeNonoperating                                    23830000
# InterestIncomeExpenseNonoperatingNet                          -107548000
# OtherNonoperatingIncomeExpense                                -115751000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -689436000
# IncomeTaxExpenseBenefit                                          7429000
# NetIncomeLoss                                                 -696865000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.64
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.64
# WeightedAverageNumberOfSharesOutstandingBasic                  263726000
# WeightedAverageNumberOfDilutedSharesOutstanding                263726000
#
#                                                    2020-01-01-2020-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            3378199000
# CostOfRevenue                                                  876042000
# OperationsAndSupportExpense                                    877901000
# ResearchAndDevelopmentExpense                                 2752872000
# SellingAndMarketingExpense                                    1175325000
# GeneralAndAdministrativeExpense                               1134851000
# RestructuringCharges                                           151355000
# CostsAndExpenses                                              6968346000
# OperatingIncomeLoss                                          -3590147000
# InvestmentIncomeNonoperating                                    27117000
# InterestIncomeExpenseNonoperatingNet                          -171688000
# OtherNonoperatingIncomeExpense                                -947220000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -4681938000
# IncomeTaxExpenseBenefit                                        -97222000
# NetIncomeLoss                                                -4584716000
# IncomeLossFromContinuingOperationsPerBasicShare                      NaN
# IncomeLossFromContinuingOperationsPerDilutedShare                    NaN
# WeightedAverageNumberOfSharesOutstandingBasic                  284363000
# WeightedAverageNumberOfDilutedSharesOutstanding                284363000
#
#                                                    2020-04-01-2020-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...             334774000
# CostOfRevenue                                                  161198000
# OperationsAndSupportExpense                                    160476000
# ResearchAndDevelopmentExpense                                  217938000
# SellingAndMarketingExpense                                     114837000
# GeneralAndAdministrativeExpense                                149299000
# RestructuringCharges                                           114241000
# CostsAndExpenses                                               917989000
# OperatingIncomeLoss                                           -583215000
# InvestmentIncomeNonoperating                                     5856000
# InterestIncomeExpenseNonoperatingNet                           -49191000
# OtherNonoperatingIncomeExpense                                 -12848000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -639398000
# IncomeTaxExpenseBenefit                                        -63810000
# NetIncomeLoss                                                 -575588000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.18
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.18
# WeightedAverageNumberOfSharesOutstandingBasic                  263517000
# WeightedAverageNumberOfDilutedSharesOutstanding                263517000
#
#                                                    2020-07-01-2020-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1342331000
# CostOfRevenue                                                  227325000
# OperationsAndSupportExpense                                    166106000
# ResearchAndDevelopmentExpense                                  213920000
# SellingAndMarketingExpense                                     113494000
# GeneralAndAdministrativeExpense                                180021000
# RestructuringCharges                                            22728000
# CostsAndExpenses                                               923594000
# OperatingIncomeLoss                                            418737000
# InvestmentIncomeNonoperating                                     4325000
# InterestIncomeExpenseNonoperatingNet                           -59867000
# OtherNonoperatingIncomeExpense                                 -56143000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             307052000
# IncomeTaxExpenseBenefit                                         87724000
# NetIncomeLoss                                                  219328000
# IncomeLossFromContinuingOperationsPerBasicShare                        0
# IncomeLossFromContinuingOperationsPerDilutedShare                      0
# WeightedAverageNumberOfSharesOutstandingBasic                  265137000
# WeightedAverageNumberOfDilutedSharesOutstanding                299206000
#
#                                                    2021-01-01-2021-03-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             886936000
# CostOfRevenue                                                  254515000
# OperationsAndSupportExpense                                    185436000
# ResearchAndDevelopmentExpense                                  363061000
# SellingAndMarketingExpense                                     229125000
# GeneralAndAdministrativeExpense                                189762000
# RestructuringCharges                                           111982000
# CostsAndExpenses                                              1333881000
# OperatingIncomeLoss                                           -446945000
# InvestmentIncomeNonoperating                                     3052000
# InterestIncomeExpenseNonoperatingNet                          -421911000
# OtherNonoperatingIncomeExpense                                -300098000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -1165902000
# IncomeTaxExpenseBenefit                                          6309000
# NetIncomeLoss                                                -1172211000
# IncomeLossFromContinuingOperationsPerBasicShare                    -1.95
# IncomeLossFromContinuingOperationsPerDilutedShare                  -1.95
# WeightedAverageNumberOfSharesOutstandingBasic                  600960000
# WeightedAverageNumberOfDilutedSharesOutstanding                600960000
#
#                                                    2021-01-01-2021-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2222132000
# CostOfRevenue                                                  548942000
# OperationsAndSupportExpense                                    393561000
# ResearchAndDevelopmentExpense                                  712795000
# SellingAndMarketingExpense                                     544448000
# GeneralAndAdministrativeExpense                                408065000
# RestructuringCharges                                           112544000
# CostsAndExpenses                                              2720355000
# OperatingIncomeLoss                                           -498223000
# InvestmentIncomeNonoperating                                     5994000
# InterestIncomeExpenseNonoperatingNet                          -428431000
# OtherNonoperatingIncomeExpense                                -302226000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -1222886000
# IncomeTaxExpenseBenefit                                         17542000
# NetIncomeLoss                                                -1240428000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.05
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.05
# WeightedAverageNumberOfSharesOutstandingBasic                  606380000
# WeightedAverageNumberOfDilutedSharesOutstanding                606380000
#
#                                                    2021-01-01-2021-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            4459564000
# CostOfRevenue                                                  860522000
# OperationsAndSupportExpense                                    621891000
# ResearchAndDevelopmentExpense                                 1057205000
# SellingAndMarketingExpense                                     835304000
# GeneralAndAdministrativeExpense                                618813000
# RestructuringCharges                                           112079000
# CostsAndExpenses                                              4105814000
# OperatingIncomeLoss                                            353750000
# InvestmentIncomeNonoperating                                     8956000
# InterestIncomeExpenseNonoperatingNet                          -435080000
# OtherNonoperatingIncomeExpense                                -300054000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -372428000
# IncomeTaxExpenseBenefit                                         34107000
# NetIncomeLoss                                                 -406535000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.67
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.67
# WeightedAverageNumberOfSharesOutstandingBasic                  611311000
# WeightedAverageNumberOfDilutedSharesOutstanding                611311000
#
#                                                    2021-01-01-2021-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            5991760000
# CostOfRevenue                                                 1155833000
# OperationsAndSupportExpense                                    847057000
# ResearchAndDevelopmentExpense                                 1425048000
# SellingAndMarketingExpense                                    1186332000
# GeneralAndAdministrativeExpense                                835324000
# RestructuringCharges                                           112849000
# CostsAndExpenses                                              5562443000
# OperatingIncomeLoss                                            429317000
# InvestmentIncomeNonoperating                                    12734000
# InterestIncomeExpenseNonoperatingNet                          -437599000
# OtherNonoperatingIncomeExpense                                -304659000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -300207000
# IncomeTaxExpenseBenefit                                         51827000
# NetIncomeLoss                                                 -352034000
# IncomeLossFromContinuingOperationsPerBasicShare                      NaN
# IncomeLossFromContinuingOperationsPerDilutedShare                    NaN
# WeightedAverageNumberOfSharesOutstandingBasic                  615891000
# WeightedAverageNumberOfDilutedSharesOutstanding                615891000
#
#                                                    2021-04-01-2021-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1335196000
# CostOfRevenue                                                  294427000
# OperationsAndSupportExpense                                    208125000
# ResearchAndDevelopmentExpense                                  349734000
# SellingAndMarketingExpense                                     315323000
# GeneralAndAdministrativeExpense                                218303000
# RestructuringCharges                                              562000
# CostsAndExpenses                                              1386474000
# OperatingIncomeLoss                                            -51278000
# InvestmentIncomeNonoperating                                     2942000
# InterestIncomeExpenseNonoperatingNet                            -6520000
# OtherNonoperatingIncomeExpense                                  -2128000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             -56984000
# IncomeTaxExpenseBenefit                                         11233000
# NetIncomeLoss                                                  -68217000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.11
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.11
# WeightedAverageNumberOfSharesOutstandingBasic                  611739000
# WeightedAverageNumberOfDilutedSharesOutstanding                611739000
#
#                                                    2021-07-01-2021-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2237432000
# CostOfRevenue                                                  311580000
# OperationsAndSupportExpense                                    228330000
# ResearchAndDevelopmentExpense                                  344410000
# SellingAndMarketingExpense                                     290856000
# GeneralAndAdministrativeExpense                                210748000
# RestructuringCharges                                             -465000
# CostsAndExpenses                                              1385459000
# OperatingIncomeLoss                                            851973000
# InvestmentIncomeNonoperating                                     2962000
# InterestIncomeExpenseNonoperatingNet                            -6649000
# OtherNonoperatingIncomeExpense                                   2172000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             850458000
# IncomeTaxExpenseBenefit                                         16565000
# NetIncomeLoss                                                  833893000
# IncomeLossFromContinuingOperationsPerBasicShare                     1.34
# IncomeLossFromContinuingOperationsPerDilutedShare                   1.22
# WeightedAverageNumberOfSharesOutstandingBasic                  621012000
# WeightedAverageNumberOfDilutedSharesOutstanding                681916000
#
#                                                    2022-01-01-2022-03-31
# RevenueFromContractWithCustomerExcludingAssesse...            1508937000
# CostOfRevenue                                                  362623000
# OperationsAndSupportExpense                                    233012000
# ResearchAndDevelopmentExpense                                  362927000
# SellingAndMarketingExpense                                     344616000
# GeneralAndAdministrativeExpense                                210573000
# RestructuringCharges                                              317000
# CostsAndExpenses                                              1514068000
# OperatingIncomeLoss                                             -5131000
# InvestmentIncomeNonoperating                                     4744000
# InterestIncomeExpenseNonoperatingNet                            -5764000
# OtherNonoperatingIncomeExpense                                  -1935000
# IncomeLossFromContinuingOperationsBeforeIncomeT...              -8086000
# IncomeTaxExpenseBenefit                                         10706000
# NetIncomeLoss                                                  -18792000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.03
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.03
# WeightedAverageNumberOfSharesOutstandingBasic                  635314000
# WeightedAverageNumberOfDilutedSharesOutstanding                635314000

# %%
from datetime import datetime

# convert string to int or float
def num(string):
    try:
        return int(string)
    except ValueError:
        return float(string)
    
# calculate 4th quarter results
# 4th quarter results are not reported seperately and have to be calculated using yearly and 9-month results
def add_fourth_quarter_results(statement):
    for column in statement:

        # ['2018', '09', '30', '2019', '09', '28']
        date_strings = [a for a in column.split('-')] 

        d0 = datetime.strptime(date_strings[0] + date_strings[1] + date_strings[2], '%Y%m%d')
        d1 = datetime.strptime(date_strings[3] + date_strings[4] + date_strings[5], '%Y%m%d')

        delta = d1 - d0

        # is annual results column
        if delta.days > 350:
            for column_1 in statement:
                date_strings_1 = [a for a in column_1.split('-')]

                d1_0 = datetime.strptime(date_strings_1[0] + date_strings_1[1] + date_strings_1[2], '%Y%m%d')
                d1_1 = datetime.strptime(date_strings_1[3] + date_strings_1[4] + date_strings_1[5], '%Y%m%d')

                delta_1 = d1_1 - d1_0

                # same starting month and 9-month results
                # calculate 4th quarter
                if d1_0 == d0 and delta_1.days > 200 and delta_1.days < 350:
                    fourth_quarter_column_name = column_1[11:] + column[10:]

                    fourth_quarter_values = []

                    for row_key, row_value in statement[column].iteritems():
                        value = num(statement[column][row_key]) - num(statement[column_1][row_key])
                        
                        if isinstance(value, float):
                            value = round(value, 2)
            
                        fourth_quarter_values.append(str(value))

                    statement[fourth_quarter_column_name] = fourth_quarter_values
 
                    # Calculate correct values of
                    # WeightedAverageNumberOfSharesOutstandingBasic = use value of annual result
                    # WeightedAverageNumberOfDilutedSharesOutstanding = use value of annual result
                    # EarningsPerShareBasic = NetIncomeLoss / WeightedAverageNumberOfSharesOutstandingBasic
                    # EarningsPerShareDiluted = NetIncomeLoss / WeightedAverageNumberOfDilutedSharesOutstanding
                    statement[fourth_quarter_column_name]["WeightedAverageNumberOfSharesOutstandingBasic"] = statement[column]["WeightedAverageNumberOfSharesOutstandingBasic"]
                    statement[fourth_quarter_column_name]["WeightedAverageNumberOfDilutedSharesOutstanding"] = statement[column]["WeightedAverageNumberOfDilutedSharesOutstanding"]

                    statement[fourth_quarter_column_name]["EarningsPerShareBasic"] = round(num(statement[fourth_quarter_column_name]["NetIncomeLoss"]) / 
                                                                                         num(statement[fourth_quarter_column_name]["WeightedAverageNumberOfSharesOutstandingBasic"]), 2)
                    
                    statement[fourth_quarter_column_name]["EarningsPerShareDiluted"] = round(num(statement[fourth_quarter_column_name]["NetIncomeLoss"]) / 
                                                                                         num(statement[fourth_quarter_column_name]["WeightedAverageNumberOfDilutedSharesOutstanding"]), 2)
                
    # sort columns
    sorted_columns = sorted(statement.columns.values)
    
    return statement[sorted_columns]

# %%
statement = income_statement_final
statement_1 = add_fourth_quarter_results(statement)

# %%
statement_1
# Out:
#                                                    2019-01-01-2019-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            4805239000
# CostOfRevenue                                                 1196313000
# OperationsAndSupportExpense                                    815074000
# ResearchAndDevelopmentExpense                                  976695000
# SellingAndMarketingExpense                                    1621519000
# GeneralAndAdministrativeExpense                                697181000
# RestructuringCharges                                                   0
# CostsAndExpenses                                              5306782000
# OperatingIncomeLoss                                           -501543000
# InvestmentIncomeNonoperating                                    85902000
# InterestIncomeExpenseNonoperatingNet                            -9968000
# OtherNonoperatingIncomeExpense                                  13906000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -411703000
# IncomeTaxExpenseBenefit                                        262636000
# NetIncomeLoss                                                 -674339000
# IncomeLossFromContinuingOperationsPerBasicShare                      NaN
# IncomeLossFromContinuingOperationsPerDilutedShare                    NaN
# WeightedAverageNumberOfSharesOutstandingBasic                  260556000
# WeightedAverageNumberOfDilutedSharesOutstanding                260556000
#
#                                                    2020-01-01-2020-03-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             841830000
# CostOfRevenue                                                  277772000
# OperationsAndSupportExpense                                    221787000
# ResearchAndDevelopmentExpense                                  258819000
# SellingAndMarketingExpense                                     317179000
# GeneralAndAdministrativeExpense                                 91762000
# RestructuringCharges                                                   0
# CostsAndExpenses                                              1167319000
# OperatingIncomeLoss                                           -325489000
# InvestmentIncomeNonoperating                                    13649000
# InterestIncomeExpenseNonoperatingNet                             1510000
# OtherNonoperatingIncomeExpense                                 -46760000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -357090000
# IncomeTaxExpenseBenefit                                        -16485000
# NetIncomeLoss                                                 -340605000
# IncomeLossFromContinuingOperationsPerBasicShare                    -1.30
# IncomeLossFromContinuingOperationsPerDilutedShare                  -1.30
# WeightedAverageNumberOfSharesOutstandingBasic                  262509000
# WeightedAverageNumberOfDilutedSharesOutstanding                262509000
#
#                                                    2020-01-01-2020-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1176604000
# CostOfRevenue                                                  438970000
# OperationsAndSupportExpense                                    382263000
# ResearchAndDevelopmentExpense                                  476757000
# SellingAndMarketingExpense                                     432016000
# GeneralAndAdministrativeExpense                                241061000
# RestructuringCharges                                           114241000
# CostsAndExpenses                                              2085308000
# OperatingIncomeLoss                                           -908704000
# InvestmentIncomeNonoperating                                    19505000
# InterestIncomeExpenseNonoperatingNet                           -47681000
# OtherNonoperatingIncomeExpense                                 -59608000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -996488000
# IncomeTaxExpenseBenefit                                        -80295000
# NetIncomeLoss                                                 -916193000
# IncomeLossFromContinuingOperationsPerBasicShare                    -3.48
# IncomeLossFromContinuingOperationsPerDilutedShare                  -3.48
# WeightedAverageNumberOfSharesOutstandingBasic                  263013000
# WeightedAverageNumberOfDilutedSharesOutstanding                263013000
#
#                                                    2020-01-01-2020-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2518935000
# CostOfRevenue                                                  666295000
# OperationsAndSupportExpense                                    548369000
# ResearchAndDevelopmentExpense                                  690677000
# SellingAndMarketingExpense                                     545510000
# GeneralAndAdministrativeExpense                                421082000
# RestructuringCharges                                           136969000
# CostsAndExpenses                                              3008902000
# OperatingIncomeLoss                                           -489967000
# InvestmentIncomeNonoperating                                    23830000
# InterestIncomeExpenseNonoperatingNet                          -107548000
# OtherNonoperatingIncomeExpense                                -115751000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -689436000
# IncomeTaxExpenseBenefit                                          7429000
# NetIncomeLoss                                                 -696865000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.64
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.64
# WeightedAverageNumberOfSharesOutstandingBasic                  263726000
# WeightedAverageNumberOfDilutedSharesOutstanding                263726000
#
#                                                    2020-01-01-2020-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            3378199000
# CostOfRevenue                                                  876042000
# OperationsAndSupportExpense                                    877901000
# ResearchAndDevelopmentExpense                                 2752872000
# SellingAndMarketingExpense                                    1175325000
# GeneralAndAdministrativeExpense                               1134851000
# RestructuringCharges                                           151355000
# CostsAndExpenses                                              6968346000
# OperatingIncomeLoss                                          -3590147000
# InvestmentIncomeNonoperating                                    27117000
# InterestIncomeExpenseNonoperatingNet                          -171688000
# OtherNonoperatingIncomeExpense                                -947220000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -4681938000
# IncomeTaxExpenseBenefit                                        -97222000
# NetIncomeLoss                                                -4584716000
# IncomeLossFromContinuingOperationsPerBasicShare                      NaN
# IncomeLossFromContinuingOperationsPerDilutedShare                    NaN
# WeightedAverageNumberOfSharesOutstandingBasic                  284363000
# WeightedAverageNumberOfDilutedSharesOutstanding                284363000
#
#                                                    2020-04-01-2020-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...             334774000
# CostOfRevenue                                                  161198000
# OperationsAndSupportExpense                                    160476000
# ResearchAndDevelopmentExpense                                  217938000
# SellingAndMarketingExpense                                     114837000
# GeneralAndAdministrativeExpense                                149299000
# RestructuringCharges                                           114241000
# CostsAndExpenses                                               917989000
# OperatingIncomeLoss                                           -583215000
# InvestmentIncomeNonoperating                                     5856000
# InterestIncomeExpenseNonoperatingNet                           -49191000
# OtherNonoperatingIncomeExpense                                 -12848000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -639398000
# IncomeTaxExpenseBenefit                                        -63810000
# NetIncomeLoss                                                 -575588000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.18
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.18
# WeightedAverageNumberOfSharesOutstandingBasic                  263517000
# WeightedAverageNumberOfDilutedSharesOutstanding                263517000
#
#                                                    2020-07-01-2020-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1342331000
# CostOfRevenue                                                  227325000
# OperationsAndSupportExpense                                    166106000
# ResearchAndDevelopmentExpense                                  213920000
# SellingAndMarketingExpense                                     113494000
# GeneralAndAdministrativeExpense                                180021000
# RestructuringCharges                                            22728000
# CostsAndExpenses                                               923594000
# OperatingIncomeLoss                                            418737000
# InvestmentIncomeNonoperating                                     4325000
# InterestIncomeExpenseNonoperatingNet                           -59867000
# OtherNonoperatingIncomeExpense                                 -56143000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             307052000
# IncomeTaxExpenseBenefit                                         87724000
# NetIncomeLoss                                                  219328000
# IncomeLossFromContinuingOperationsPerBasicShare                        0
# IncomeLossFromContinuingOperationsPerDilutedShare                      0
# WeightedAverageNumberOfSharesOutstandingBasic                  265137000
# WeightedAverageNumberOfDilutedSharesOutstanding                299206000
#
#                                                    2020-09-30-2020-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             859264000
# CostOfRevenue                                                  209747000
# OperationsAndSupportExpense                                    329532000
# ResearchAndDevelopmentExpense                                 2062195000
# SellingAndMarketingExpense                                     629815000
# GeneralAndAdministrativeExpense                                713769000
# RestructuringCharges                                            14386000
# CostsAndExpenses                                              3959444000
# OperatingIncomeLoss                                          -3100180000
# InvestmentIncomeNonoperating                                     3287000
# InterestIncomeExpenseNonoperatingNet                           -64140000
# OtherNonoperatingIncomeExpense                                -831469000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -3992502000
# IncomeTaxExpenseBenefit                                       -104651000
# NetIncomeLoss                                                -3887851000
# IncomeLossFromContinuingOperationsPerBasicShare                      nan
# IncomeLossFromContinuingOperationsPerDilutedShare                    nan
# WeightedAverageNumberOfSharesOutstandingBasic                  284363000
# WeightedAverageNumberOfDilutedSharesOutstanding                284363000
#
#                                                    2021-01-01-2021-03-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             886936000
# CostOfRevenue                                                  254515000
# OperationsAndSupportExpense                                    185436000
# ResearchAndDevelopmentExpense                                  363061000
# SellingAndMarketingExpense                                     229125000
# GeneralAndAdministrativeExpense                                189762000
# RestructuringCharges                                           111982000
# CostsAndExpenses                                              1333881000
# OperatingIncomeLoss                                           -446945000
# InvestmentIncomeNonoperating                                     3052000
# InterestIncomeExpenseNonoperatingNet                          -421911000
# OtherNonoperatingIncomeExpense                                -300098000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -1165902000
# IncomeTaxExpenseBenefit                                          6309000
# NetIncomeLoss                                                -1172211000
# IncomeLossFromContinuingOperationsPerBasicShare                    -1.95
# IncomeLossFromContinuingOperationsPerDilutedShare                  -1.95
# WeightedAverageNumberOfSharesOutstandingBasic                  600960000
# WeightedAverageNumberOfDilutedSharesOutstanding                600960000
#
#                                                    2021-01-01-2021-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2222132000
# CostOfRevenue                                                  548942000
# OperationsAndSupportExpense                                    393561000
# ResearchAndDevelopmentExpense                                  712795000
# SellingAndMarketingExpense                                     544448000
# GeneralAndAdministrativeExpense                                408065000
# RestructuringCharges                                           112544000
# CostsAndExpenses                                              2720355000
# OperatingIncomeLoss                                           -498223000
# InvestmentIncomeNonoperating                                     5994000
# InterestIncomeExpenseNonoperatingNet                          -428431000
# OtherNonoperatingIncomeExpense                                -302226000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -1222886000
# IncomeTaxExpenseBenefit                                         17542000
# NetIncomeLoss                                                -1240428000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.05
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.05
# WeightedAverageNumberOfSharesOutstandingBasic                  606380000
# WeightedAverageNumberOfDilutedSharesOutstanding                606380000
#
#                                                    2021-01-01-2021-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            4459564000
# CostOfRevenue                                                  860522000
# OperationsAndSupportExpense                                    621891000
# ResearchAndDevelopmentExpense                                 1057205000
# SellingAndMarketingExpense                                     835304000
# GeneralAndAdministrativeExpense                                618813000
# RestructuringCharges                                           112079000
# CostsAndExpenses                                              4105814000
# OperatingIncomeLoss                                            353750000
# InvestmentIncomeNonoperating                                     8956000
# InterestIncomeExpenseNonoperatingNet                          -435080000
# OtherNonoperatingIncomeExpense                                -300054000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -372428000
# IncomeTaxExpenseBenefit                                         34107000
# NetIncomeLoss                                                 -406535000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.67
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.67
# WeightedAverageNumberOfSharesOutstandingBasic                  611311000
# WeightedAverageNumberOfDilutedSharesOutstanding                611311000
#
#                                                    2021-01-01-2021-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            5991760000
# CostOfRevenue                                                 1155833000
# OperationsAndSupportExpense                                    847057000
# ResearchAndDevelopmentExpense                                 1425048000
# SellingAndMarketingExpense                                    1186332000
# GeneralAndAdministrativeExpense                                835324000
# RestructuringCharges                                           112849000
# CostsAndExpenses                                              5562443000
# OperatingIncomeLoss                                            429317000
# InvestmentIncomeNonoperating                                    12734000
# InterestIncomeExpenseNonoperatingNet                          -437599000
# OtherNonoperatingIncomeExpense                                -304659000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -300207000
# IncomeTaxExpenseBenefit                                         51827000
# NetIncomeLoss                                                 -352034000
# IncomeLossFromContinuingOperationsPerBasicShare                      NaN
# IncomeLossFromContinuingOperationsPerDilutedShare                    NaN
# WeightedAverageNumberOfSharesOutstandingBasic                  615891000
# WeightedAverageNumberOfDilutedSharesOutstanding                615891000
#
#                                                    2021-04-01-2021-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1335196000
# CostOfRevenue                                                  294427000
# OperationsAndSupportExpense                                    208125000
# ResearchAndDevelopmentExpense                                  349734000
# SellingAndMarketingExpense                                     315323000
# GeneralAndAdministrativeExpense                                218303000
# RestructuringCharges                                              562000
# CostsAndExpenses                                              1386474000
# OperatingIncomeLoss                                            -51278000
# InvestmentIncomeNonoperating                                     2942000
# InterestIncomeExpenseNonoperatingNet                            -6520000
# OtherNonoperatingIncomeExpense                                  -2128000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             -56984000
# IncomeTaxExpenseBenefit                                         11233000
# NetIncomeLoss                                                  -68217000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.11
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.11
# WeightedAverageNumberOfSharesOutstandingBasic                  611739000
# WeightedAverageNumberOfDilutedSharesOutstanding                611739000
#
#                                                    2021-07-01-2021-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2237432000
# CostOfRevenue                                                  311580000
# OperationsAndSupportExpense                                    228330000
# ResearchAndDevelopmentExpense                                  344410000
# SellingAndMarketingExpense                                     290856000
# GeneralAndAdministrativeExpense                                210748000
# RestructuringCharges                                             -465000
# CostsAndExpenses                                              1385459000
# OperatingIncomeLoss                                            851973000
# InvestmentIncomeNonoperating                                     2962000
# InterestIncomeExpenseNonoperatingNet                            -6649000
# OtherNonoperatingIncomeExpense                                   2172000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             850458000
# IncomeTaxExpenseBenefit                                         16565000
# NetIncomeLoss                                                  833893000
# IncomeLossFromContinuingOperationsPerBasicShare                     1.34
# IncomeLossFromContinuingOperationsPerDilutedShare                   1.22
# WeightedAverageNumberOfSharesOutstandingBasic                  621012000
# WeightedAverageNumberOfDilutedSharesOutstanding                681916000
#
#                                                    2021-09-30-2021-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            1532196000
# CostOfRevenue                                                  295311000
# OperationsAndSupportExpense                                    225166000
# ResearchAndDevelopmentExpense                                  367843000
# SellingAndMarketingExpense                                     351028000
# GeneralAndAdministrativeExpense                                216511000
# RestructuringCharges                                              770000
# CostsAndExpenses                                              1456629000
# OperatingIncomeLoss                                             75567000
# InvestmentIncomeNonoperating                                     3778000
# InterestIncomeExpenseNonoperatingNet                            -2519000
# OtherNonoperatingIncomeExpense                                  -4605000
# IncomeLossFromContinuingOperationsBeforeIncomeT...              72221000
# IncomeTaxExpenseBenefit                                         17720000
# NetIncomeLoss                                                   54501000
# IncomeLossFromContinuingOperationsPerBasicShare                      nan
# IncomeLossFromContinuingOperationsPerDilutedShare                    nan
# WeightedAverageNumberOfSharesOutstandingBasic                  615891000
# WeightedAverageNumberOfDilutedSharesOutstanding                615891000
#
#                                                    2022-01-01-2022-03-31
# RevenueFromContractWithCustomerExcludingAssesse...            1508937000
# CostOfRevenue                                                  362623000
# OperationsAndSupportExpense                                    233012000
# ResearchAndDevelopmentExpense                                  362927000
# SellingAndMarketingExpense                                     344616000
# GeneralAndAdministrativeExpense                                210573000
# RestructuringCharges                                              317000
# CostsAndExpenses                                              1514068000
# OperatingIncomeLoss                                             -5131000
# InvestmentIncomeNonoperating                                     4744000
# InterestIncomeExpenseNonoperatingNet                            -5764000
# OtherNonoperatingIncomeExpense                                  -1935000
# IncomeLossFromContinuingOperationsBeforeIncomeT...              -8086000
# IncomeTaxExpenseBenefit                                         10706000
# NetIncomeLoss                                                  -18792000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.03
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.03
# WeightedAverageNumberOfSharesOutstandingBasic                  635314000
# WeightedAverageNumberOfDilutedSharesOutstanding                635314000

# %%
# remove all non-quarterly columns
def only_quarterly_results(statement):
    for column in statement:
        # convert all strings to int
        date_strings = [a for a in column.split('-')]

        d0 = datetime.strptime(date_strings[0] + date_strings[1] + date_strings[2], '%Y%m%d')
        d1 = datetime.strptime(date_strings[3] + date_strings[4] + date_strings[5], '%Y%m%d')
        delta = d1 - d0

        # column represents more timeframe longer than one quarter
        if delta.days > 100:
            statement = statement.drop(column, axis=1)
    return statement

# %%
qrt_income_statement = only_quarterly_results(statement_1)
qrt_income_statement
# Out:
#                                                    2020-01-01-2020-03-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             841830000
# CostOfRevenue                                                  277772000
# OperationsAndSupportExpense                                    221787000
# ResearchAndDevelopmentExpense                                  258819000
# SellingAndMarketingExpense                                     317179000
# GeneralAndAdministrativeExpense                                 91762000
# RestructuringCharges                                                   0
# CostsAndExpenses                                              1167319000
# OperatingIncomeLoss                                           -325489000
# InvestmentIncomeNonoperating                                    13649000
# InterestIncomeExpenseNonoperatingNet                             1510000
# OtherNonoperatingIncomeExpense                                 -46760000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -357090000
# IncomeTaxExpenseBenefit                                        -16485000
# NetIncomeLoss                                                 -340605000
# IncomeLossFromContinuingOperationsPerBasicShare                    -1.30
# IncomeLossFromContinuingOperationsPerDilutedShare                  -1.30
# WeightedAverageNumberOfSharesOutstandingBasic                  262509000
# WeightedAverageNumberOfDilutedSharesOutstanding                262509000
#
#                                                    2020-04-01-2020-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...             334774000
# CostOfRevenue                                                  161198000
# OperationsAndSupportExpense                                    160476000
# ResearchAndDevelopmentExpense                                  217938000
# SellingAndMarketingExpense                                     114837000
# GeneralAndAdministrativeExpense                                149299000
# RestructuringCharges                                           114241000
# CostsAndExpenses                                               917989000
# OperatingIncomeLoss                                           -583215000
# InvestmentIncomeNonoperating                                     5856000
# InterestIncomeExpenseNonoperatingNet                           -49191000
# OtherNonoperatingIncomeExpense                                 -12848000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            -639398000
# IncomeTaxExpenseBenefit                                        -63810000
# NetIncomeLoss                                                 -575588000
# IncomeLossFromContinuingOperationsPerBasicShare                    -2.18
# IncomeLossFromContinuingOperationsPerDilutedShare                  -2.18
# WeightedAverageNumberOfSharesOutstandingBasic                  263517000
# WeightedAverageNumberOfDilutedSharesOutstanding                263517000
#
#                                                    2020-07-01-2020-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1342331000
# CostOfRevenue                                                  227325000
# OperationsAndSupportExpense                                    166106000
# ResearchAndDevelopmentExpense                                  213920000
# SellingAndMarketingExpense                                     113494000
# GeneralAndAdministrativeExpense                                180021000
# RestructuringCharges                                            22728000
# CostsAndExpenses                                               923594000
# OperatingIncomeLoss                                            418737000
# InvestmentIncomeNonoperating                                     4325000
# InterestIncomeExpenseNonoperatingNet                           -59867000
# OtherNonoperatingIncomeExpense                                 -56143000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             307052000
# IncomeTaxExpenseBenefit                                         87724000
# NetIncomeLoss                                                  219328000
# IncomeLossFromContinuingOperationsPerBasicShare                        0
# IncomeLossFromContinuingOperationsPerDilutedShare                      0
# WeightedAverageNumberOfSharesOutstandingBasic                  265137000
# WeightedAverageNumberOfDilutedSharesOutstanding                299206000
#
#                                                    2020-09-30-2020-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             859264000
# CostOfRevenue                                                  209747000
# OperationsAndSupportExpense                                    329532000
# ResearchAndDevelopmentExpense                                 2062195000
# SellingAndMarketingExpense                                     629815000
# GeneralAndAdministrativeExpense                                713769000
# RestructuringCharges                                            14386000
# CostsAndExpenses                                              3959444000
# OperatingIncomeLoss                                          -3100180000
# InvestmentIncomeNonoperating                                     3287000
# InterestIncomeExpenseNonoperatingNet                           -64140000
# OtherNonoperatingIncomeExpense                                -831469000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -3992502000
# IncomeTaxExpenseBenefit                                       -104651000
# NetIncomeLoss                                                -3887851000
# IncomeLossFromContinuingOperationsPerBasicShare                      nan
# IncomeLossFromContinuingOperationsPerDilutedShare                    nan
# WeightedAverageNumberOfSharesOutstandingBasic                  284363000
# WeightedAverageNumberOfDilutedSharesOutstanding                284363000
#
#                                                    2021-01-01-2021-03-31  \
# RevenueFromContractWithCustomerExcludingAssesse...             886936000
# CostOfRevenue                                                  254515000
# OperationsAndSupportExpense                                    185436000
# ResearchAndDevelopmentExpense                                  363061000
# SellingAndMarketingExpense                                     229125000
# GeneralAndAdministrativeExpense                                189762000
# RestructuringCharges                                           111982000
# CostsAndExpenses                                              1333881000
# OperatingIncomeLoss                                           -446945000
# InvestmentIncomeNonoperating                                     3052000
# InterestIncomeExpenseNonoperatingNet                          -421911000
# OtherNonoperatingIncomeExpense                                -300098000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           -1165902000
# IncomeTaxExpenseBenefit                                          6309000
# NetIncomeLoss                                                -1172211000
# IncomeLossFromContinuingOperationsPerBasicShare                    -1.95
# IncomeLossFromContinuingOperationsPerDilutedShare                  -1.95
# WeightedAverageNumberOfSharesOutstandingBasic                  600960000
# WeightedAverageNumberOfDilutedSharesOutstanding                600960000
#
#                                                    2021-04-01-2021-06-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            1335196000
# CostOfRevenue                                                  294427000
# OperationsAndSupportExpense                                    208125000
# ResearchAndDevelopmentExpense                                  349734000
# SellingAndMarketingExpense                                     315323000
# GeneralAndAdministrativeExpense                                218303000
# RestructuringCharges                                              562000
# CostsAndExpenses                                              1386474000
# OperatingIncomeLoss                                            -51278000
# InvestmentIncomeNonoperating                                     2942000
# InterestIncomeExpenseNonoperatingNet                            -6520000
# OtherNonoperatingIncomeExpense                                  -2128000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             -56984000
# IncomeTaxExpenseBenefit                                         11233000
# NetIncomeLoss                                                  -68217000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.11
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.11
# WeightedAverageNumberOfSharesOutstandingBasic                  611739000
# WeightedAverageNumberOfDilutedSharesOutstanding                611739000
#
#                                                    2021-07-01-2021-09-30  \
# RevenueFromContractWithCustomerExcludingAssesse...            2237432000
# CostOfRevenue                                                  311580000
# OperationsAndSupportExpense                                    228330000
# ResearchAndDevelopmentExpense                                  344410000
# SellingAndMarketingExpense                                     290856000
# GeneralAndAdministrativeExpense                                210748000
# RestructuringCharges                                             -465000
# CostsAndExpenses                                              1385459000
# OperatingIncomeLoss                                            851973000
# InvestmentIncomeNonoperating                                     2962000
# InterestIncomeExpenseNonoperatingNet                            -6649000
# OtherNonoperatingIncomeExpense                                   2172000
# IncomeLossFromContinuingOperationsBeforeIncomeT...             850458000
# IncomeTaxExpenseBenefit                                         16565000
# NetIncomeLoss                                                  833893000
# IncomeLossFromContinuingOperationsPerBasicShare                     1.34
# IncomeLossFromContinuingOperationsPerDilutedShare                   1.22
# WeightedAverageNumberOfSharesOutstandingBasic                  621012000
# WeightedAverageNumberOfDilutedSharesOutstanding                681916000
#
#                                                    2021-09-30-2021-12-31  \
# RevenueFromContractWithCustomerExcludingAssesse...            1532196000
# CostOfRevenue                                                  295311000
# OperationsAndSupportExpense                                    225166000
# ResearchAndDevelopmentExpense                                  367843000
# SellingAndMarketingExpense                                     351028000
# GeneralAndAdministrativeExpense                                216511000
# RestructuringCharges                                              770000
# CostsAndExpenses                                              1456629000
# OperatingIncomeLoss                                             75567000
# InvestmentIncomeNonoperating                                     3778000
# InterestIncomeExpenseNonoperatingNet                            -2519000
# OtherNonoperatingIncomeExpense                                  -4605000
# IncomeLossFromContinuingOperationsBeforeIncomeT...              72221000
# IncomeTaxExpenseBenefit                                         17720000
# NetIncomeLoss                                                   54501000
# IncomeLossFromContinuingOperationsPerBasicShare                      nan
# IncomeLossFromContinuingOperationsPerDilutedShare                    nan
# WeightedAverageNumberOfSharesOutstandingBasic                  615891000
# WeightedAverageNumberOfDilutedSharesOutstanding                615891000
#
#                                                    2022-01-01-2022-03-31
# RevenueFromContractWithCustomerExcludingAssesse...            1508937000
# CostOfRevenue                                                  362623000
# OperationsAndSupportExpense                                    233012000
# ResearchAndDevelopmentExpense                                  362927000
# SellingAndMarketingExpense                                     344616000
# GeneralAndAdministrativeExpense                                210573000
# RestructuringCharges                                              317000
# CostsAndExpenses                                              1514068000
# OperatingIncomeLoss                                             -5131000
# InvestmentIncomeNonoperating                                     4744000
# InterestIncomeExpenseNonoperatingNet                            -5764000
# OtherNonoperatingIncomeExpense                                  -1935000
# IncomeLossFromContinuingOperationsBeforeIncomeT...              -8086000
# IncomeTaxExpenseBenefit                                         10706000
# NetIncomeLoss                                                  -18792000
# IncomeLossFromContinuingOperationsPerBasicShare                    -0.03
# IncomeLossFromContinuingOperationsPerDilutedShare                  -0.03
# WeightedAverageNumberOfSharesOutstandingBasic                  635314000
# WeightedAverageNumberOfDilutedSharesOutstanding                635314000

# %%
qrt_income_statement.transpose().to_csv('.\Data\Cleaned_Data\SEC_Fin_Data/ABNB_SEC_Fin_qrts')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import numpy as np

# custom y axis formatter
def format_dollars(y, pos=None):
    return int(y/1000000000)

fig, ax = plt.subplots(1, 1, figsize=(8, 6))

ax = qrt_income_statement.astype(float)\
                         .loc["NetIncomeLoss"]\
                         .plot.line(legend=True)
ax = qrt_income_statement.astype(float)\
                         .loc["RevenueFromContractWithCustomerExcludingAssessedTax"]\
                         .plot.line(legend=True)

ax.set_title('Quarterly Revenues and Net Income')

ax.yaxis.set_major_formatter(tick.FuncFormatter(format_dollars))

plt.ylabel('$ Billions')

# show all quarter date ranges
plt.xticks(ticks=np.arange(len(qrt_income_statement.columns)),
           labels=qrt_income_statement.columns)

# format x axis properly
fig.autofmt_xdate()

plt.show()

# %%
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots(1, 1, figsize=(8, 6))

ax = qrt_income_statement.astype(float).loc["EarningsPerShareBasic"].plot.line()

ax.set_title('Earnings Per Share Basic')

# use higher precision for y axis labels
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

plt.xticks(ticks=np.arange(len(qrt_income_statement.columns)),
           labels=qrt_income_statement.columns)

# format x axis properly
fig.autofmt_xdate()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EarningsPerShareBasic'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18492/2003011332.py in <module>
#       3 fig, ax = plt.subplots(1, 1, figsize=(8, 6))
#       4
# ----> 5 ax = qrt_income_statement.astype(float).loc["EarningsPerShareBasic"].plot.line()
#       6
#       7 ax.set_title('Earnings Per Share Basic')
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# c:\Users\jhg55\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'EarningsPerShareBasic'
